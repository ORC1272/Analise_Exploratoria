# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-talk')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import datetime
from IPython.display import display
df = pd.read_excel('/content/drive/MyDrive/AdventureWorks.xlsx')

# %%
pd.options.display.float_format='{:20,.2f}'.format

# %%
df.groupby (df['Data Venda'].dt.year) ['Lucro'].sum().plot.bar(title= 'faturamento 2008 x 2009');

# %%
df.groupby([df['Data Venda'].dt.year,'Marca']) ['Lucro'].sum().plot.barh(title= 'faturamento 2008 x 2009 Lucratividade por Marca');

# %%
df.groupby([df['Data Venda'].dt.year,'ID Loja']) ['Lucro'].sum().plot.bar(title= 'faturamento 2008 x 2009 Lucratividade por Loja');

# %%
df.groupby('ID Loja')['Valor Venda','Lucro','Custo','Valor Desconto'].sum().plot.bar(title= 'Resumo comercial por Loja');

# %%
df.groupby ('Produto') ['Valor Venda'].sum().plot.barh(title= 'Faturamento por produto');

# %%
df['Classe'].value_counts().plot.pie(title= 'Representativida por Classe');

# %%
plt.boxplot(df['Preço Unitário']);

# %%
plt.hist(df['Valor Venda']);

# %%
df.groupby('ID Loja')['Valor Venda','Custo','Lucro'].sum().plot.bar();

# %%
df.groupby('ID Loja')['Valor Venda','Custo'].sum().plot.bar();

# %%
df.groupby('ID Loja')['Valor Venda', 'Valor Desconto'].sum().plot.bar();

# %%
df.groupby ('ID Produto') ['Valor Venda'].sum().plot.barh();

# %%
df['Marca'].value_counts().plot.barh();

# %%
df['ID Loja'].value_counts().plot.barh();

# %%
df['Cor'].value_counts().plot.bar();

# %%
df['Produto'].value_counts().plot.barh();

# %%
df.groupby ('Produto') ['Quantidade'].sum().plot.barh();

# %%
df ['Valor Venda'].sum()
# Out:
# 5984606.1426

# %% [markdown]
# # Nova seção

# %%
df ['Lucro_Bruto'] = df ['Valor Venda'] - (df ['Custo'])
df.Lucro_Bruto.sum()
# Out:
# 3497823.0926

# %%
df["Custo"] = df["Custo Unitário"].mul(df["Quantidade"])

# %%
df["Lucro"] = df["Valor Venda"] - (df["Custo"])

# %%
df.describe()
# Out:
#           ID Loja   ID Produto  ...         Lucro   Lucro_Bruto
# count  904.000000   904.000000  ...    904.000000    904.000000
# mean   270.015487  1225.238938  ...   3869.273333   3869.273333
# std     50.955280   706.698742  ...   2823.813548   2823.813548
# min    199.000000   366.000000  ...     78.400000     78.400000
# 25%    199.000000   384.000000  ...   2001.720000   2001.720000
# 50%    306.000000  1202.000000  ...   3405.240000   3405.240000
# 75%    307.000000  1226.000000  ...   4670.680000   4670.680000
# max    307.000000  2497.000000  ...  19659.300000  19659.300000
#
# [8 rows x 11 columns]

# %%
df.shape
# Out:
# (904, 16)

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
df['Valor Desconto'].value_counts()
# Out:
# 0.0       299
# 1176.0     23
# 606.4      23
# 909.6      21
# 798.4      18
#          ...
# 75.8        1
# 480.2       1
# 1098.9      1
# 2195.6      1
# 548.9       1
# Name: Valor Desconto, Length: 158, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data Venda      904 non-null    datetime64[ns]
#  1   Data Envio      904 non-null    datetime64[ns]
#  2   ID Loja         904 non-null    int64
#  3   ID Produto      904 non-null    int64
#  4   ID Cliente      904 non-null    int64
#  5   No. Venda       904 non-null    object
#  6   Custo Unitário  904 non-null    float64
#  7   Preço Unitário  904 non-null    float64
#  8   Quantidade      904 non-null    int64
#  9   Valor Desconto  904 non-null    float64
#  10  Valor Venda     904 non-null    float64
#  11  Produto         904 non-null    object
#  12  Fabricante      904 non-null    object
#  13  Marca           904 non-null    object
#  14  Classe          904 non-null    object
#  15  Cor             904 non-null    object
# ...

# %%
df['Valor Desconto'].value_counts().sum
# Out:
# <bound method Series.sum of 0.0       299
# 1176.0     23
# 606.4      23
# 909.6      21
# 798.4      18
#          ...
# 75.8        1
# 480.2       1
# 1098.9      1
# 2195.6      1
# 548.9       1
# Name: Valor Desconto, Length: 158, dtype: int64>

# %%
df['Valor Desconto'].mean()
# Out:
# 689.1232935840726

# %%
df['Valor Desconto'].max
# Out:
# <bound method Series.max of 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.00
#         ...
# 899     419.58
# 900    1176.00
# 901    1176.00
# 902    1198.80
# 903    1176.00
# Name: Valor Desconto, Length: 904, dtype: float64>

# %%
df['Valor Desconto'].min
# Out:
# <bound method Series.min of 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.00
#         ...
# 899     419.58
# 900    1176.00
# 901    1176.00
# 902    1198.80
# 903    1176.00
# Name: Valor Desconto, Length: 904, dtype: float64>

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# dtype: int64

# %%
df['Valor Venda'].max
# Out:
# <bound method Series.max of 0      4548.00
# 1      4548.00
# 2      4548.00
# 3      4548.00
# 4      4548.00
#         ...
# 899    5574.42
# 900    4704.00
# 901    4704.00
# 902    4795.20
# 903    4704.00
# Name: Valor Venda, Length: 904, dtype: float64>

# %%
df[df['Valor Venda'] == 5574.42]
# Out:
#     Data Venda Data Envio  ...                Lucro          Lucro_Bruto
# 899 2008-03-22 2008-04-04  ...             3,588.48             3,588.48
#
# [1 rows x 18 columns]

# %%
df['Valor Venda'] == 5574.42
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 899     True
# 900    False
# 901    False
# 902    False
# 903    False
# Name: Valor Venda, Length: 904, dtype: bool

# %%
df.nlargest(5,'Valor Venda')
# Out:
#     Data Venda Data Envio  ID Loja  ...     Marca   Classe    Cor
# 236 2008-04-13 2008-04-19      199  ...  Fabrikam  Regular  Black
# 493 2008-07-22 2008-08-01      199  ...  Fabrikam  Regular  Black
# 339 2008-12-16 2008-12-27      199  ...  Fabrikam  Regular   Grey
# 234 2008-05-02 2008-05-13      199  ...  Fabrikam  Regular  Black
# 235 2008-06-22 2008-06-29      306  ...  Fabrikam  Regular  Black
#
# [5 rows x 16 columns]

# %%
df.to_csv('desafio_analise_pandas.csv', index=False)
